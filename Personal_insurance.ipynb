# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv(r"C:\\Users\\Pranjal\Desktop\data\insurance lifestyle.csv")

# %%
from sklearn import preprocessing 
label_encoder = preprocessing.LabelEncoder() 
df['Vacation Type']= label_encoder.fit_transform(df['Vacation Type'])
df['Brand concious']= label_encoder.fit_transform(df['Brand concious'])
df['Hobbies']= label_encoder.fit_transform(df['Hobbies'])
df['Existing Insurance Coverage']= label_encoder.fit_transform(df['Existing Insurance Coverage'])
df['Medical History']= label_encoder.fit_transform(df['Medical History'])
df['Living Region']= label_encoder.fit_transform(df['Living Region'])
df['Gender']= label_encoder.fit_transform(df['Gender'])
df['Insurance Type']= label_encoder.fit_transform(df['Insurance Type'])
df
# Out:
#     No of Vehicle  Vacations/Year  Vacation Type  Brand concious  Hobbies  \
# 0               1               2              0               1        3
# 1               2               2              0               0        0
# 2               0               3              0               1        3
# 3               1               1              1               1        3
# 4               4               4              1               1        1
# 5               1               2              0               0        3
# 6               3               5              1               1        2
# 7               0               3              0               0        0
# 8               1               1              0               0        3
# 9               3               1              1               1        1
# 10              1               2              0               0        2
# 11              2               6              1               1        1
# ...

# %%
from sklearn import linear_model
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.svm import SVC 
x=['No of Vehicle','Vacations/Year','Vacation Type','Brand concious','Hobbies',	'Existing Insurance Coverage','Medical History','Living Region','bmi','Age','Gender','Salary']
y1=['Insurance Type']
X=df[x]
y=df[y1]
x_train,x_test,y_train,y_test=train_test_split(X,y,random_state=0)
dtree_model = DecisionTreeClassifier(max_depth = 2).fit(x_train, y_train) 
y_pred=dtree_model.predict(x_test)
print('Test Accuracy Score: ',metrics.accuracy_score(y_test,y_pred))
# Out:
# Test Accuracy Score:  0.875

# %%
from sklearn.cluster import KMeans
km=KMeans(n_clusters=5)
y_pred=km.fit_predict(df[['Insurance Type']])
y_pred
# Out:
# C:\Users\Pranjal\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1008: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# array([0, 2, 0, 2, 1, 2, 1, 0, 0, 1, 2, 1, 2, 0, 2, 1, 2, 2, 1, 1, 2, 1,
#        2, 0, 2, 0, 1, 0, 2, 2])

# %% [markdown]
# Correlation

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df1=df[['No of Vehicle','Vacations/Year','Vacation Type','Brand concious','Hobbies',	'Existing Insurance Coverage','Medical History','Living Region','bmi','Age','Gender','Salary']]
cor=df1.corr()
sns.heatmap(cor, square = True)

# %% [markdown]
# Conclusion

# %% [markdown]
# Here,I use mutliclass algorithm decision tree classifier and get 87% accuracy
